# %% [markdown]
# <a href="https://www.kaggle.com/code/idowuadamo/mnist-from-dense-networks-to-cnns?scriptVersionId=201614125" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import L2
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Data

# %%
mnist_train = pd.read_csv('/kaggle/input/digit-recognizer/train.csv')

mnist_test = pd.read_csv('/kaggle/input/digit-recognizer/test.csv')

# %%
# Count the occurrences of each class
class_counts = mnist_train['label'].value_counts().sort_index()

# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(class_counts.index, class_counts.values, align='center')
plt.title('Distribution of Classes in MNIST Training Dataset')
plt.xlabel('Digit')
plt.ylabel('Number of Samples')
plt.xticks(range(10))

# Add value labels on top of each bar
for i, count in enumerate(class_counts):
    plt.text(i, count, str(count), ha='center', va='bottom')

# Show the plot
plt.show()

# %%
X = mnist_train.drop(columns=['label'])
y = mnist_train['label']

# %%
X.shape
# Out:
# (42000, 784)

# %%
# Normalize pixel values to be between 0 and 1
X = X / 255.0
mnist_test = mnist_test / 255.0

# %%
# Splitting the dataset into training and validation sets 
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
#print(X_train.shape)
#print(y_train.shape)

# %%
X_reshaped = X_train.to_numpy().reshape(-1,28,28,1) 

plt.figure(figsize=(15,5))
for i in range(30): 
    plt.subplot(3,10, i+1) 
    plt.imshow(X_reshaped[i, :, :, 0], cmap=plt.cm.binary) 
    plt.axis('off') 
plt.subplots_adjust(wspace=-0.1, hspace=-0.1) 
plt.show()

# %% [markdown]
# # Dense Neural Network

# %%
input_shape = [X_train.shape[1]]

# Define the model
model = Sequential([
    Dense(units=128, activation='relu', input_shape= input_shape),
    Dense(units=64, activation='relu'),
    Dense(units=10, activation='softmax')
])

# %%
# Compile the model
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    epochs=30,
)
# Out:
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729138615.161718      70 service.cc:145] XLA service 0x7a4544009120 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1729138615.161772      70 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1729138615.161778      70 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#  107/1182 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5748 - loss: 1.4484
# I0000 00:00:1729138616.763878      70 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8515 - loss: 0.5204 - val_accuracy: 0.9557 - val_loss: 0.1610
# Epoch 2/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9636 - loss: 0.1257 - val_accuracy: 0.9621 - val_loss: 0.1271
# Epoch 3/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9766 - loss: 0.0780 - val_accuracy: 0.9669 - val_loss: 0.1113
# Epoch 4/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9808 - loss: 0.0614 - val_accuracy: 0.9705 - val_loss: 0.0969
# Epoch 5/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9870 - loss: 0.0418 - val_accuracy: 0.9731 - val_loss: 0.0921
# Epoch 6/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9897 - loss: 0.0317 - val_accuracy: 0.9695 - val_loss: 0.1186
# Epoch 7/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9910 - loss: 0.0266 - val_accuracy: 0.9714 - val_loss: 0.1145
# Epoch 8/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9928 - loss: 0.0209 - val_accuracy: 0.9698 - val_loss: 0.1092
# Epoch 9/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9939 - loss: 0.0187 - val_accuracy: 0.9748 - val_loss: 0.1044
# Epoch 10/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9943 - loss: 0.0168 - val_accuracy: 0.9721 - val_loss: 0.1155
# Epoch 11/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9963 - loss: 0.0112 - val_accuracy: 0.9743 - val_loss: 0.1074
# Epoch 12/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9970 - loss: 0.0098 - val_accuracy: 0.9733 - val_loss: 0.1170
# Epoch 13/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9963 - loss: 0.0115 - val_accuracy: 0.9710 - val_loss: 0.1398
# Epoch 14/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9961 - loss: 0.0141 - val_accuracy: 0.9664 - val_loss: 0.1599
# Epoch 15/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9971 - loss: 0.0100 - val_accuracy: 0.9760 - val_loss: 0.1333
# Epoch 16/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9955 - loss: 0.0127 - val_accuracy: 0.9731 - val_loss: 0.1595
# Epoch 17/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9971 - loss: 0.0080 - val_accuracy: 0.9743 - val_loss: 0.1394
# Epoch 18/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9966 - loss: 0.0107 - val_accuracy: 0.9733 - val_loss: 0.1717
# Epoch 19/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9961 - loss: 0.0114 - val_accuracy: 0.9748 - val_loss: 0.1466
# Epoch 20/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9977 - loss: 0.0067 - val_accuracy: 0.9750 - val_loss: 0.1322
# Epoch 21/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0082 - val_accuracy: 0.9740 - val_loss: 0.1601
# Epoch 22/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9975 - loss: 0.0077 - val_accuracy: 0.9760 - val_loss: 0.1321
# Epoch 23/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9983 - loss: 0.0061 - val_accuracy: 0.9733 - val_loss: 0.1551
# Epoch 24/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9970 - loss: 0.0102 - val_accuracy: 0.9738 - val_loss: 0.1545
# Epoch 25/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9959 - loss: 0.0164 - val_accuracy: 0.9743 - val_loss: 0.1644
# Epoch 26/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9988 - loss: 0.0038 - val_accuracy: 0.9745 - val_loss: 0.1550
# Epoch 27/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9982 - loss: 0.0059 - val_accuracy: 0.9748 - val_loss: 0.1567
# Epoch 28/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9970 - loss: 0.0095 - val_accuracy: 0.9743 - val_loss: 0.1739
# Epoch 29/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9987 - loss: 0.0036 - val_accuracy: 0.9755 - val_loss: 0.1600
# Epoch 30/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9993 - loss: 0.0028 - val_accuracy: 0.9705 - val_loss: 0.2292

# %%
history_df = pd.DataFrame(history.history)

# Plot accuracy
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.legend()
plt.show()

# %% [markdown]
# The model is performing significantly better on the training data compared to the validation data, indicating overfitting. Overfitting occurs when the model captures too much noise from the training set, preventing the loss from being as low as possible. To address this, we will increase the model's capacity and implement early stopping, which will stop training once the validation loss stops decreasing.

# %%
model = Sequential([
    BatchNormalization(input_shape=input_shape),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.4),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(
    patience=15,
    min_delta=0.001,
    restore_best_weights=True,
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=256,
    epochs=500,
    callbacks=[early_stopping], 
    verbose=0,  # turn off training log
)

# %%
history_df = pd.DataFrame(history.history)

# Plot accuracy
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.legend()
plt.show()

# %% [markdown]
# The results are promising, but we will take it a step further by implementing a CNN, which is better suited for our dataset.

# %% [markdown]
# # CNN

# %%
# Function to convert and reshape data to 2D
def convert_and_reshape(data):
    if isinstance(data, pd.DataFrame):
        return data.to_numpy().reshape(-1, 28, 28, 1)
    elif isinstance(data, np.ndarray):
        return data.reshape(-1, 28, 28, 1)
    else:
        raise TypeError("Input must be a pandas DataFrame or a numpy array")

# Converting and reshaping X_train
X_train = convert_and_reshape(X_train)

# Converting and reshaping X_valid
X_valid = convert_and_reshape(X_valid)

# Converting and reshaping X_test
X_test = convert_and_reshape(mnist_test)

# %%
# Define the model
model = tf.keras.Sequential([
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),
    
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),
    
    layers.Conv2D(128, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.2),
    
    # Classifier Head
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
#model.summary()

# %%
# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    epochs=30,
)
# Out:
# Epoch 1/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - accuracy: 0.7695 - loss: 0.6941 - val_accuracy: 0.9714 - val_loss: 0.1016
# Epoch 2/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9624 - loss: 0.1262 - val_accuracy: 0.9779 - val_loss: 0.0719
# Epoch 3/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9689 - loss: 0.0975 - val_accuracy: 0.9821 - val_loss: 0.0563
# Epoch 4/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9749 - loss: 0.0774 - val_accuracy: 0.9819 - val_loss: 0.0604
# Epoch 5/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9779 - loss: 0.0706 - val_accuracy: 0.9838 - val_loss: 0.0481
# Epoch 6/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9807 - loss: 0.0616 - val_accuracy: 0.9857 - val_loss: 0.0475
# Epoch 7/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9823 - loss: 0.0538 - val_accuracy: 0.9862 - val_loss: 0.0436
# Epoch 8/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9837 - loss: 0.0517 - val_accuracy: 0.9862 - val_loss: 0.0443
# Epoch 9/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9849 - loss: 0.0477 - val_accuracy: 0.9864 - val_loss: 0.0479
# Epoch 10/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9866 - loss: 0.0408 - val_accuracy: 0.9895 - val_loss: 0.0433
# Epoch 11/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9888 - loss: 0.0354 - val_accuracy: 0.9888 - val_loss: 0.0379
# Epoch 12/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9875 - loss: 0.0359 - val_accuracy: 0.9886 - val_loss: 0.0456
# Epoch 13/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9869 - loss: 0.0387 - val_accuracy: 0.9876 - val_loss: 0.0427
# Epoch 14/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9882 - loss: 0.0358 - val_accuracy: 0.9890 - val_loss: 0.0381
# Epoch 15/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9903 - loss: 0.0289 - val_accuracy: 0.9876 - val_loss: 0.0439
# Epoch 16/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9894 - loss: 0.0333 - val_accuracy: 0.9883 - val_loss: 0.0461
# Epoch 17/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9899 - loss: 0.0304 - val_accuracy: 0.9893 - val_loss: 0.0431
# Epoch 18/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9898 - loss: 0.0298 - val_accuracy: 0.9867 - val_loss: 0.0470
# Epoch 19/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9919 - loss: 0.0275 - val_accuracy: 0.9871 - val_loss: 0.0520
# Epoch 20/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9915 - loss: 0.0269 - val_accuracy: 0.9890 - val_loss: 0.0434
# Epoch 21/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9922 - loss: 0.0256 - val_accuracy: 0.9902 - val_loss: 0.0370
# Epoch 22/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9927 - loss: 0.0235 - val_accuracy: 0.9900 - val_loss: 0.0361
# Epoch 23/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9918 - loss: 0.0241 - val_accuracy: 0.9893 - val_loss: 0.0341
# Epoch 24/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9925 - loss: 0.0240 - val_accuracy: 0.9905 - val_loss: 0.0350
# Epoch 25/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9915 - loss: 0.0256 - val_accuracy: 0.9898 - val_loss: 0.0445
# Epoch 26/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9919 - loss: 0.0239 - val_accuracy: 0.9902 - val_loss: 0.0399
# Epoch 27/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9931 - loss: 0.0196 - val_accuracy: 0.9902 - val_loss: 0.0339
# Epoch 28/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9931 - loss: 0.0211 - val_accuracy: 0.9902 - val_loss: 0.0340
# Epoch 29/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9924 - loss: 0.0255 - val_accuracy: 0.9890 - val_loss: 0.0362
# Epoch 30/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9929 - loss: 0.0205 - val_accuracy: 0.9895 - val_loss: 0.0363

# %%
history_df = pd.DataFrame(history.history)

# Plot accuracy
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.legend()
plt.show()

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# Data augmentation is a technique used to artificially increase the size and diversity of a training dataset by applying various transformations to existing images.
#
# Common augmentation techniques include:
#
# 1. Rotation: Slightly rotating the digits (usually within a small range, e.g., ±10 degrees).
# 2. Zooming: Slightly increasing or decreasing the size of the digit.
# 3. Width and height shifts: Moving the digit up, down, left, or right.
#
# These transformations help the model learn to recognize digits in various orientations and styles, potentially improving its generalization capabilities.

# %%
datagen = ImageDataGenerator(
    rotation_range=5,  # Rotate the image by up to 5 degrees
    width_shift_range=0.1,  # Shift the image horizontally by up to 10% of its width
    height_shift_range=0.1,  # Shift the image vertically by up to 10% of its height
    zoom_range=0.1,  # Zoom in or out by up to 10%
    fill_mode='nearest'  # Fill in newly created pixels using the nearest neighbor
)

datagen.fit(X_train) 

#datagen = ImageDataGenerator( rotation_range=6,
                             #zoom_range=0.07,
                             #width_shift_range=0.09,
                             #height_shift_range=0.06,
                             #shear_range=3)

#datagen.fit(X_train)

# %%
from tensorflow.keras import layers

model = tf.keras.Sequential([
    layers.Conv2D(filters=32, kernel_size=(3,3), activation="relu", padding='same', input_shape=[28, 28, 1]),
    layers.BatchNormalization(),
    layers.MaxPool2D(),
    layers.Dropout(0.3),
    
    layers.Conv2D(filters=64, kernel_size=(3,3), activation="relu", padding='same'),
    layers.BatchNormalization(),
    layers.MaxPool2D(),
    layers.Dropout(0.3),
    
    layers.Conv2D(filters=64, kernel_size=(3,3), activation="relu", padding='same'),
    layers.BatchNormalization(),
    layers.MaxPool2D(),
    layers.Dropout(0.4),
    
    layers.Flatten(),
    layers.Dense(units=64, activation="relu"),
    layers.Dropout(0.3),
    layers.Dense(units=10, activation="softmax"),
])

#print(model.summary())

# %%
# compile the model
model.compile(optimizer= Adam(learning_rate=0.001),
              loss= 'sparse_categorical_crossentropy',
              metrics= ['accuracy'])

# %%
# Early Stopping
#early_stopping = tf.keras.callbacks.EarlyStopping( 
#    monitor='val_loss',
#    patience=10,
#    restore_best_weights=True)

# Train the model
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=32),
    epochs=50,
    validation_data=(X_valid, y_valid)
)  
    #callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 33s 20ms/step - accuracy: 0.5266 - loss: 1.4359 - val_accuracy: 0.9702 - val_loss: 0.0889
# Epoch 2/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9172 - loss: 0.2765 - val_accuracy: 0.9821 - val_loss: 0.0539
# Epoch 3/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9412 - loss: 0.1949 - val_accuracy: 0.9762 - val_loss: 0.0789
# Epoch 4/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9512 - loss: 0.1636 - val_accuracy: 0.9867 - val_loss: 0.0428
# Epoch 5/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9578 - loss: 0.1436 - val_accuracy: 0.9900 - val_loss: 0.0296
# Epoch 6/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - accuracy: 0.9619 - loss: 0.1313 - val_accuracy: 0.9886 - val_loss: 0.0337
# Epoch 7/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - accuracy: 0.9641 - loss: 0.1254 - val_accuracy: 0.9907 - val_loss: 0.0308
# Epoch 8/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - accuracy: 0.9647 - loss: 0.1192 - val_accuracy: 0.9914 - val_loss: 0.0267
# Epoch 9/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - accuracy: 0.9696 - loss: 0.1049 - val_accuracy: 0.9895 - val_loss: 0.0376
# Epoch 10/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9704 - loss: 0.0993 - val_accuracy: 0.9910 - val_loss: 0.0300
# Epoch 11/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9716 - loss: 0.0928 - val_accuracy: 0.9902 - val_loss: 0.0286
# Epoch 12/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.9724 - loss: 0.0932 - val_accuracy: 0.9933 - val_loss: 0.0228
# Epoch 13/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9740 - loss: 0.0909 - val_accuracy: 0.9912 - val_loss: 0.0221
# Epoch 14/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9748 - loss: 0.0840 - val_accuracy: 0.9924 - val_loss: 0.0264
# Epoch 15/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9755 - loss: 0.0873 - val_accuracy: 0.9900 - val_loss: 0.0313
# Epoch 16/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.9775 - loss: 0.0799 - val_accuracy: 0.9907 - val_loss: 0.0300
# Epoch 17/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - accuracy: 0.9751 - loss: 0.0852 - val_accuracy: 0.9914 - val_loss: 0.0270
# Epoch 18/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9752 - loss: 0.0886 - val_accuracy: 0.9943 - val_loss: 0.0192
# Epoch 19/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9780 - loss: 0.0739 - val_accuracy: 0.9943 - val_loss: 0.0202
# Epoch 20/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9775 - loss: 0.0768 - val_accuracy: 0.9933 - val_loss: 0.0214
# Epoch 21/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9786 - loss: 0.0756 - val_accuracy: 0.9938 - val_loss: 0.0209
# Epoch 22/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9780 - loss: 0.0771 - val_accuracy: 0.9938 - val_loss: 0.0220
# Epoch 23/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.9779 - loss: 0.0769 - val_accuracy: 0.9938 - val_loss: 0.0203
# Epoch 24/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9787 - loss: 0.0708 - val_accuracy: 0.9933 - val_loss: 0.0220
# Epoch 25/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9777 - loss: 0.0731 - val_accuracy: 0.9938 - val_loss: 0.0208
# Epoch 26/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9816 - loss: 0.0638 - val_accuracy: 0.9950 - val_loss: 0.0202
# Epoch 27/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - accuracy: 0.9792 - loss: 0.0708 - val_accuracy: 0.9926 - val_loss: 0.0212
# Epoch 28/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - accuracy: 0.9791 - loss: 0.0670 - val_accuracy: 0.9948 - val_loss: 0.0197
# Epoch 29/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9808 - loss: 0.0681 - val_accuracy: 0.9943 - val_loss: 0.0219
# Epoch 30/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9792 - loss: 0.0674 - val_accuracy: 0.9938 - val_loss: 0.0212
# Epoch 31/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9800 - loss: 0.0701 - val_accuracy: 0.9940 - val_loss: 0.0209
# Epoch 32/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9821 - loss: 0.0605 - val_accuracy: 0.9933 - val_loss: 0.0206
# Epoch 33/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9822 - loss: 0.0628 - val_accuracy: 0.9929 - val_loss: 0.0229
# Epoch 34/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9818 - loss: 0.0613 - val_accuracy: 0.9933 - val_loss: 0.0202
# Epoch 35/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9815 - loss: 0.0638 - val_accuracy: 0.9938 - val_loss: 0.0215
# Epoch 36/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9828 - loss: 0.0590 - val_accuracy: 0.9943 - val_loss: 0.0197
# Epoch 37/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9811 - loss: 0.0656 - val_accuracy: 0.9940 - val_loss: 0.0184
# Epoch 38/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - accuracy: 0.9836 - loss: 0.0596 - val_accuracy: 0.9940 - val_loss: 0.0174
# Epoch 39/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9822 - loss: 0.0628 - val_accuracy: 0.9952 - val_loss: 0.0175
# Epoch 40/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - accuracy: 0.9834 - loss: 0.0563 - val_accuracy: 0.9931 - val_loss: 0.0193
# Epoch 41/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9827 - loss: 0.0607 - val_accuracy: 0.9950 - val_loss: 0.0171
# Epoch 42/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - accuracy: 0.9840 - loss: 0.0587 - val_accuracy: 0.9940 - val_loss: 0.0198
# Epoch 43/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9821 - loss: 0.0624 - val_accuracy: 0.9943 - val_loss: 0.0201
# Epoch 44/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 15s 13ms/step - accuracy: 0.9841 - loss: 0.0528 - val_accuracy: 0.9943 - val_loss: 0.0176
# Epoch 45/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9822 - loss: 0.0582 - val_accuracy: 0.9936 - val_loss: 0.0198
# Epoch 46/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9837 - loss: 0.0544 - val_accuracy: 0.9938 - val_loss: 0.0208
# Epoch 47/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9832 - loss: 0.0584 - val_accuracy: 0.9933 - val_loss: 0.0206
# Epoch 48/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9843 - loss: 0.0562 - val_accuracy: 0.9926 - val_loss: 0.0272
# Epoch 49/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9843 - loss: 0.0562 - val_accuracy: 0.9940 - val_loss: 0.0194
# Epoch 50/50
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.9837 - loss: 0.0546 - val_accuracy: 0.9950 - val_loss: 0.0159

# %%
history_df = pd.DataFrame(history.history)

# Plot accuracy
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.legend()
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
# 1. Make predictions on the validation set
y_pred_probs = model.predict(X_valid)  # Predict probabilities
y_pred = np.argmax(y_pred_probs, axis=1)  # Convert probabilities to class labels

# 2. Generate the confusion matrix
conf_matrix = confusion_matrix(y_valid, y_pred)

# 3. Define class names (digits 0 to 9)
class_names = [i for i in range(10)]

# 4. Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %% [markdown]
# # Submission

# %%
predictions = model.predict(X_test, batch_size=128)
# Out:
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
predicted_classes = np.argmax(predictions, axis=1)

# %%
submission_df = pd.DataFrame({
    'ImageId': range(1, len(predicted_classes) + 1),
    'Label': predicted_classes
})
submission_df.to_csv('submission.csv', index=False)

# %%
#submission_df

# %% [markdown]
# Thank you for exploring this notebook! If you enjoyed it and found value in the content, please consider giving it an upvote ⬆️. Your support means a lot to me and encourages me to create more helpful notebooks
